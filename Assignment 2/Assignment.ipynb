# %%
'''
final Q1
i) Assume P(ω1) =0.8; P(ω2)=0.2 
ii)  Assume P(ω1) = P(ω2) 
 
ω1 = [1,6; 3,4; 3,8; 5,6] ω2 = [3,0; 1,-2;3,-4;5,-2] 

'''

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sympy import *
from sympy import plot, symbols
from sympy.plotting.plot import List2DSeries
# %matplotlib notebook

x1 = [1,3,3,5]
y1 = [6,4,8,6] 

x2 = [3,1,3,5]
y2 = [0,-2,-4,-2]

w1 = pd.DataFrame({"x":x1, "y": y1 })
print(w1)

w2 = pd.DataFrame({"x":x2, "y":y2 })
print(w2)

P_w1 = 0.8
P_w2 = 0.2

#calculate covariance matrix for class w1
w1_x_mean = np.mean(w1["x"])
w1_y_mean = np.mean(w1["y"])

# w1_y_mean

w1_mean = np.array([[w1_x_mean,w1_y_mean]])
print(w1_mean)

w1_mean1 = np.tile(w1_mean,(len(w1),1))

#find Z matrix
w1_Z = w1 - w1_mean1
w1_Z

# #Covariance matrix
w1_cov = (np.dot(w1_Z.T, w1_Z))/(w1.shape[0]-1)
print("w1 Covariance: \n",w1_cov)

#Cov matrix inverse
w1_cov_inv = np.linalg.inv(w1_cov)
# w1_cov_inv

#calculate covariance matrix for class w2
w2_x_mean = np.mean(w2["x"])
w2_y_mean = np.mean(w2["y"])

# w2_y_mean

w2_mean = np.array([[w2_x_mean,w2_y_mean]])
print(w2_mean)

w2_mean1 = np.tile(w2_mean,(len(w2),1))

#find Z matrix
w2_Z = w2 - w2_mean1
w2_Z

# #Covariance matrix
w2_cov = (np.dot(w2_Z.T, w2_Z))/(w2.shape[0]-1)
print("w2 Covariance: \n",w2_cov)

#Cov matrix inverse
w2_cov_inv = np.linalg.inv(w2_cov)
# w1_cov_inv


#finding decision boundary

#checking case 1: 

#sigma^2 or variance
var_w1 = w1_cov[0][0]
if np.array_equal(w1_cov, (var_w1*np.eye(w1_cov.shape[0]))) and np.array_equal(w2_cov, (var_w1*np.eye(w2_cov.shape[0]))):
    print("case1")
elif np.array_equal(w1_cov, w2_cov): 
    print("case2")
else:
    print("Case3")
    
    
x,y = symbols('x y')
X=Matrix([[x,y]]).T


g1 = X.T.dot((-0.5*w1_cov_inv).dot(X)) + (np.dot(w1_cov_inv,w1_mean.T)).T.dot(X) -0.5*np.dot(w1_mean,np.dot(w1_cov_inv, w1_mean.T)) - 0.5*np.log(np.linalg.det(w1_cov))
g2 = X.T.dot((-0.5*w2_cov_inv).dot(X)) + (np.dot(w2_cov_inv,w2_mean.T)).T.dot(X) -0.5*np.dot(w2_mean,np.dot(w2_cov_inv, w2_mean.T)) - 0.5*np.log(np.linalg.det(w2_cov))

boundary = g1-g2
b = boundary[0][0]
print(b)


#plot boundary
plot_implicit(b,(x,-10,10), (y,-10,10))

plt.scatter(x1,y1, label = "w1")
plt.scatter(x2,y2, label = "w2")

# plt.legend()
# sympy.plot(x1,y1)
plt.show()
# Out:
#    x  y
# 0  1  6
# 1  3  4
# 2  3  8
# 3  5  6
#    x  y
# 0  3  0
# 1  1 -2
# 2  3 -4
# 3  5 -2
# [[3. 6.]]
# w1 Covariance:
#  [[2.66666667 0.        ]
#  [0.         2.66666667]]
# [[ 3. -2.]]
# w2 Covariance:
#  [[2.66666667 0.        ]
#  [0.         2.66666667]]
# case1
# 3.0*y - 6.0
# <img src="data:image/png;base64,..." width="640">

# %%
'''
final Q2
ω1 = [1,-1; 2,-5; 3,-6; 4,-10; 5,-12; 6,-15] ω2 = [-1,1; -2,5; -3,6; -4,10, -5,12; -6, 15]

'''

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sympy import *
from sympy import plot, symbols
from sympy.plotting.plot import List2DSeries
# %matplotlib notebook

x1 = [1,2,3,4,5,6]
y1 = [-1,-5,-6,-10,-13,-15] 

x2 = [-1,-2,-3,-4,-5,-6]
y2 = [1,5,6,10,12,15]

w1 = pd.DataFrame({"x":x1, "y": y1 })
print(w1)

w2 = pd.DataFrame({"x":x2, "y":y2 })
print(w2)

P_w1 = 0.3
P_w2 = 0.7

#calculate covariance matrix for class w1
w1_x_mean = np.mean(w1["x"])
w1_y_mean = np.mean(w1["y"])

# w1_y_mean

w1_mean = np.array([[w1_x_mean,w1_y_mean]])
print(w1_mean)

w1_mean1 = np.tile(w1_mean,(len(x1),1))

#find Z matrix
w1_Z = w1 - w1_mean1
w1_Z

# #Covariance matrix
w1_cov = (np.dot(w1_Z.T, w1_Z))/(w1.shape[0]-1)
print("w1 Covariance: \n",w1_cov)

#Cov matrix inverse
w1_cov_inv = np.linalg.inv(w1_cov)
# w1_cov_inv

#calculate covariance matrix for class w2
w2_x_mean = np.mean(w2["x"])
w2_y_mean = np.mean(w2["y"])

# w2_y_mean

w2_mean = np.array([[w2_x_mean,w2_y_mean]])
print(w2_mean)

w2_mean1 = np.tile(w2_mean,(len(x1),1))

#find Z matrix
w2_Z = w2 - w2_mean1
w2_Z

# #Covariance matrix
w2_cov = (np.dot(w2_Z.T, w2_Z))/(w2.shape[0]-1)
print("w2 Covariance: \n",w2_cov)

#Cov matrix inverse
w2_cov_inv = np.linalg.inv(w2_cov)
# w1_cov_inv


#finding decision boundary

#checking case 1: 

#sigma^2 or variance
var_w1 = w1_cov[0][0]
if np.array_equal(w1_cov, (var_w1*np.eye(w1_cov.shape[0]))) and np.array_equal(w2_cov, (var_w1*np.eye(w2_cov.shape[0]))):
    print("case1")
elif np.array_equal(w1_cov, w2_cov): 
    print("case2")
else:
    print("Case3")
    
    
x,y = symbols('x y')
X=Matrix([["x","y"]]).T


g1 = X.T.dot((-0.5*w1_cov_inv).dot(X)) + (np.dot(w1_cov_inv,w1_mean.T)).T.dot(X) -0.5*np.dot(w1_mean,np.dot(w1_cov_inv, w1_mean.T)) - 0.5*np.log(np.linalg.det(w1_cov))
g2 = X.T.dot((-0.5*w2_cov_inv).dot(X)) + (np.dot(w2_cov_inv,w2_mean.T)).T.dot(X) -0.5*np.dot(w2_mean,np.dot(w2_cov_inv, w2_mean.T)) - 0.5*np.log(np.linalg.det(w2_cov))

boundary = g1-g2
b = boundary[0][0]
print(b)

#plot boundary
plot_implicit(b,(x,-6,6), (y,-15,15))

plt.scatter(x1,y1, label = "w1")
plt.scatter(x2,y2, label = "w2")

plt.legend()
plt.show()
# Out:
#    x   y
# 0  1  -1
# 1  2  -5
# 2  3  -6
# 3  4 -10
# 4  5 -13
# 5  6 -15
#    x   y
# 0 -1   1
# 1 -2   5
# 2 -3   6
# 3 -4  10
# 4 -5  12
# 5 -6  15
# [[ 3.5        -8.33333333]]
# w1 Covariance:
#  [[ 3.5        -9.8       ]
#  [-9.8        27.86666667]]
# [[-3.5         8.16666667]]
# w2 Covariance:
#  [[ 3.5        -9.5       ]
#  [-9.5        26.16666667]]
# Case3
# -x*(-9.8125000000001*x - 3.56250000000004*y) + x*(-9.33035714285733*x - 3.28125000000007*y) + 21.1250000000003*x - y*(-3.56250000000004*x - 1.31250000000001*y) + y*(-3.28125000000007*x - 1.17187500000002*y) + 6.93750000000011*y - 0.244164342653507
# <img src="data:image/png;base64,..." width="640">

# %%
'''
final Q3
ω1 = [2,6; 3,4; 3,8; 4,6] 
ω2 = [3,0; 1,-2; 3,-4; 5,-2]

'''

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sympy import *
from sympy import plot, symbols
from sympy.plotting.plot import List2DSeries
# %matplotlib notebook

x1 = [2,3,3,4]
y1 = [6,4,8,6] 

x2 = [3,1,3,5]
y2 = [0,-2,-4,-2]

w1 = pd.DataFrame({"x":x1, "y": y1 })
print(w1)

w2 = pd.DataFrame({"x":x2, "y":y2 })
print(w2)

P_w1 = 0.3
P_w2 = 0.7

#calculate covariance matrix for class w1
w1_x_mean = np.mean(w1["x"])
w1_y_mean = np.mean(w1["y"])

# w1_y_mean

w1_mean = np.array([[w1_x_mean,w1_y_mean]])
print(w1_mean)

w1_mean1 = np.tile(w1_mean,(len(x1),1))

#find Z matrix
w1_Z = w1 - w1_mean1
w1_Z

# #Covariance matrix
w1_cov = (np.dot(w1_Z.T, w1_Z))/(w1.shape[0]-1)
print("w1 Covariance: \n",w1_cov)

#Cov matrix inverse
w1_cov_inv = np.linalg.inv(w1_cov)
# w1_cov_inv

#calculate covariance matrix for class w2
w2_x_mean = np.mean(w2["x"])
w2_y_mean = np.mean(w2["y"])

# w2_y_mean

w2_mean = np.array([[w2_x_mean,w2_y_mean]])
print(w2_mean)

w2_mean1 = np.tile(w2_mean,(len(x1),1))

#find Z matrix
w2_Z = w2 - w2_mean1
w2_Z

# #Covariance matrix
w2_cov = (np.dot(w2_Z.T, w2_Z))/(w2.shape[0]-1)
print("w2 Covariance: \n",w2_cov)

#Cov matrix inverse
w2_cov_inv = np.linalg.inv(w2_cov)
# w1_cov_inv


#finding decision boundary

#checking case 1: 

#sigma^2 or variance
var_w1 = w1_cov[0][0]
if np.array_equal(w1_cov, (var_w1*np.eye(w1_cov.shape[0]))) and np.array_equal(w2_cov, (var_w1*np.eye(w2_cov.shape[0]))):
    print("case1")
elif np.array_equal(w1_cov, w2_cov): 
    print("case2")
else:
    print("Case3")
    
    
x,y = symbols('x y')
X=Matrix([["x","y"]]).T


g1 = X.T.dot((-0.5*w1_cov_inv).dot(X)) + (np.dot(w1_cov_inv,w1_mean.T)).T.dot(X) -0.5*np.dot(w1_mean,np.dot(w1_cov_inv, w1_mean.T)) - 0.5*np.log(np.linalg.det(w1_cov))
g2 = X.T.dot((-0.5*w2_cov_inv).dot(X)) + (np.dot(w2_cov_inv,w2_mean.T)).T.dot(X) -0.5*np.dot(w2_mean,np.dot(w2_cov_inv, w2_mean.T)) - 0.5*np.log(np.linalg.det(w2_cov))

boundary = g1-g2
b = boundary[0][0]
print(b)

#plot boundary
plot_implicit(b,(x,1,5), (y,-4,8))

plt.scatter(x1,y1, label = "w1")
plt.scatter(x2,y2, label = "w2")

plt.legend()
plt.show()
# Out:
#    x  y
# 0  2  6
# 1  3  4
# 2  3  8
# 3  4  6
#    x  y
# 0  3  0
# 1  1 -2
# 2  3 -4
# 3  5 -2
# [[3. 6.]]
# w1 Covariance:
#  [[0.66666667 0.        ]
#  [0.         2.66666667]]
# [[ 3. -2.]]
# w2 Covariance:
#  [[2.66666667 0.        ]
#  [0.         2.66666667]]
# Case3
# -0.5625*x**2 + 3.375*x + 3.0*y - 10.3693528194401
# <img src="data:image/png;base64,..." width="640">

# %%
'''
Q5. Use only two features: Petal Length and Petal Width, for 3 class classification 
draw the decision boundary between them (2 dimension, 3 regions also called as multi-class problem)
'''

'''
final Q3
ω1 = [2,6; 3,4; 3,8; 4,6] 
ω2 = [3,0; 1,-2; 3,-4; 5,-2]

'''

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sympy import *
from sympy import plot, symbols
from sympy.plotting.plot import List2DSeries
# %matplotlib notebook


df = pd.read_csv("iris.csv")

w1 = df.iloc[0:50,[2,3]]    #Setosa_dist   #each distribution must have 50 data each (check using shape)  
w2 = df.iloc[50:100,[2,3]]     #Versi_dist
w3 = df.iloc[100:151,[2,3]]      #Virginica_dist


P_w1 = 50/150
P_w2 = 50/150
P_w3 = 50/150

#calculate covariance matrix for class w1
w1_x_mean = np.mean(w1["petal.length"])
w1_y_mean = np.mean(w1["petal.width"])

# w1_y_mean

w1_mean = np.array([[w1_x_mean,w1_y_mean]])
print(w1_mean)

w1_mean1 = np.tile(w1_mean,(w1.shape[0],1))

#find Z matrix
w1_Z = w1 - w1_mean1
# w1_Z

#Covariance matrix
w1_cov = (np.dot(w1_Z.T, w1_Z))/(w1.shape[0]-1)
print("w1 Covariance: \n",w1_cov)

#Cov matrix inverse
w1_cov_inv = np.linalg.inv(w1_cov)
# w1_cov_inv

#calculate covariance matrix for class w2
w2_x_mean = np.mean(w2["petal.length"])
w2_y_mean = np.mean(w2["petal.width"])

# w2_y_mean

w2_mean = np.array([[w2_x_mean,w2_y_mean]])
print(w2_mean)

w2_mean1 = np.tile(w2_mean,(w2.shape[0],1))

#find Z matrix
w2_Z = w2 - w2_mean1
w2_Z

# #Covariance matrix
w2_cov = (np.dot(w2_Z.T, w2_Z))/(w2.shape[0]-1)
print("w2 Covariance: \n",w2_cov)

#Cov matrix inverse
w2_cov_inv = np.linalg.inv(w2_cov)
# w1_cov_inv

#calculate covariance matrix for class w3
w3_x_mean = np.mean(w3["petal.length"])
w3_y_mean = np.mean(w3["petal.width"])

# w2_y_mean

w3_mean = np.array([[w3_x_mean,w3_y_mean]])
print(w3_mean)

w3_mean1 = np.tile(w3_mean,(w3.shape[0],1))

#find Z matrix
w3_Z = w3 - w3_mean1
w3_Z

# #Covariance matrix
w3_cov = (np.dot(w3_Z.T, w3_Z))/(w3.shape[0]-1)
print("w3 Covariance: \n",w3_cov)

#Cov matrix inverse
w3_cov_inv = np.linalg.inv(w3_cov)


#finding decision boundary
    
    
x,y = symbols('x y')
X=Matrix([["x","y"]]).T


g1 = X.T.dot((-0.5*w1_cov_inv).dot(X)) + (np.dot(w1_cov_inv,w1_mean.T)).T.dot(X) -0.5*np.dot(w1_mean,np.dot(w1_cov_inv, w1_mean.T)) - 0.5*np.log(np.linalg.det(w1_cov))
g2 = X.T.dot((-0.5*w2_cov_inv).dot(X)) + (np.dot(w2_cov_inv,w2_mean.T)).T.dot(X) -0.5*np.dot(w2_mean,np.dot(w2_cov_inv, w2_mean.T)) - 0.5*np.log(np.linalg.det(w2_cov))
g3 = X.T.dot((-0.5*w3_cov_inv).dot(X)) + (np.dot(w3_cov_inv,w3_mean.T)).T.dot(X) -0.5*np.dot(w3_mean,np.dot(w3_cov_inv, w3_mean.T)) - 0.5*np.log(np.linalg.det(w3_cov))

boundary = g1-g2
b = boundary[0][0]
print(b)

#plot boundary
plot_implicit(b,(x,0,7), (y,0,3))

# plt.figure(figsize=(5,5))
# sns.lmplot('petal.length', 'petal.width', data=df, hue='variety', fit_reg=False)
# sns.scatterplot('petal.length', 'petal.width', data=df, hue='variety')

# plt.title("Plot after plotting testcases points ")

plt.scatter(w1["petal.length"],w1["petal.width"], label = "Setosa")
plt.scatter(w2["petal.length"],w2["petal.width"], label = "Versicolor")
plt.scatter(w3["petal.length"],w3["petal.width"], label = "Virginica")
plt.legend()

plt.show()
# Out:
# [[1.462 0.246]]
# w1 Covariance:
#  [[0.03015918 0.00606939]
#  [0.00606939 0.01110612]]
# [[4.26  1.326]]
# w2 Covariance:
#  [[0.22081633 0.07310204]
#  [0.07310204 0.03910612]]
# [[5.552 2.026]]
# w3 Covariance:
#  [[0.30458776 0.04882449]
#  [0.04882449 0.07543265]]
# x*(-18.6273003135076*x + 10.1796382088151*y) - x*(-5.94072047539025*x + 11.1051355510113*y) + 28.2937251489164*x + y*(10.1796382088151*x - 50.5832862978714*y) - y*(11.1051355510113*x - 33.5448259804418*y) + 0.776591130462162*y + 6.97752556981448
# <img src="data:image/png;base64,..." width="640">
